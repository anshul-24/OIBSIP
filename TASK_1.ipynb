# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# %%
data=pd.read_csv('C:/Users/Desktop/Downloads/Oasis Infobyte/TASK_3/Iris.csv')
data.head(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.drop('Id',axis=1,inplace=True)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# How many datapoints /rows are present in species?

data["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.figure(figsize=(5,2),dpi=100)
plt.scatter(data.SepalLengthCm,data.Species)

plt.title('Iris Chart',size=30,c='blue')

plt.xlabel('Sepal Length Cm',size=30,c='black')
plt.ylabel('Species',size=30,c='black')

plt.grid()
plt.show()

# %%
plt.figure(figsize=(5,2),dpi=100)
plt.scatter(data.SepalWidthCm,data.Species)

plt.title('Iris Chart',size=30,c='blue')

plt.xlabel('Sepal Width Cm',size=30,c='black')
plt.ylabel('Species',size=30,c='black')

plt.grid()
plt.show()

# %%
plt.figure(figsize=(5,2),dpi=100)
plt.scatter(data.PetalLengthCm,data.Species)

plt.title('Iris Chart',size=30,c='blue')

plt.xlabel('Petal Length Cm',size=30,c='black')
plt.ylabel('Species',size=30,c='black')

plt.grid()
plt.show()

# %%
plt.figure(figsize=(5,2),dpi=100)
plt.scatter(data.PetalWidthCm,data.Species)

plt.title('Iris Chart',size=30,c='blue')

plt.xlabel('Petal Width Cm',size=30,c='black')
plt.ylabel('Species',size=30,c='black')

plt.grid()
plt.show()

# %%
#Analyze and visualize the dataset:
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# Visualize the whole dataset
#Pair Plot(ScatterPlot)

import seaborn as sns
sns.set_style("whitegrid")
sns.pairplot(data,hue='Species', height=5)
plt.show()

# %%
sns.pairplot(data=data,kind='scatter')

# %%
#Distribution plot

data.hist(edgecolor='blue', linewidth=1.2,)
fig=plt.gcf()
fig.set_size_inches(8,4)

# %%
#Stacked Histogram

data['Species'] = data['Species'].astype('category')

list1=list()
mylabels=list()
for gen in data.Species.cat.categories:
    list1.append(data[data.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
# Do the train/test split

X= data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y= data['Species']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
# Training the Linear Regression Model

from sklearn.linear_model import LogisticRegression

# %%
# Let's create an instance for the LogisticRegression model
model = LogisticRegression()

# Train the model on our train dataset
model.fit(X,y)

# Train the model with the training set

model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# Getting predictions from the model for the given examples.
predictions = model.predict(X)

# Compare with the actual charges

Scores = pd.DataFrame({'Actual':y,'Predictions':predictions})
Scores.head(150)
# Out:
#              Actual     Predictions
# 0       Iris-setosa     Iris-setosa
# 1       Iris-setosa     Iris-setosa
# 2       Iris-setosa     Iris-setosa
# 3       Iris-setosa     Iris-setosa
# 4       Iris-setosa     Iris-setosa
# ..              ...             ...
# 145  Iris-virginica  Iris-virginica
# 146  Iris-virginica  Iris-virginica
# 147  Iris-virginica  Iris-virginica
# 148  Iris-virginica  Iris-virginica
# 149  Iris-virginica  Iris-virginica
#
# [150 rows x 2 columns]

# %%
y_test_hat=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_test_hat)*100,'%')
# Out:
# 100.0 %
